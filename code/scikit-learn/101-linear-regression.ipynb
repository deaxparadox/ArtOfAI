# %%
from sklearn.linear_model import LinearRegression
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error , root_mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

# %%
X = [
    [0, 1],
    [1, 1],
    [2, 2],
]
y = [0, 1, 2]

# %%
reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([1.00000000e+00, 7.35066553e-17])

# %% [markdown]
# # Examples

# %%
# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# Use only one feature
diabetes_X =  diabetes_X[:, np.newaxis, 2]

# Split the data into training/testing sets
# diabetes_X_train = diabetes_X[:-20]
# diabetes_X_test = diabetes_X_train[-20:]

# Split the targets into trainig/testing sets
# diabetes_y_train = diabetes_y[:-20]
# diabetes_y_test = diabetes_y[-20:]
diabetes_X_test, diabetes_X_train, diabetes_y_test, diabetes_y_train = train_test_split(diabetes_X, diabetes_y, test_size=.1)

# Create linear regression object
regr = LinearRegression()

# Train the model using the trainig sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# %%
# The coefficients
print("Coefficients: \n", regr.coef_)

# The mean squared error
print("Mean squared: %.2f" % mean_squared_error(diabetes_y_test, diabetes_y_pred))

# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(diabetes_y_test, diabetes_y_pred))
# Out:
# Coefficients:
#  [684.71759186]
# Mean squared: 4036.10
# Coefficient of determination: 0.32

# %%
# The coefficients
print("Coefficients: \n", regr.coef_)

# The mean squared error
print("Mean squared: %.2f" % root_mean_squared_error(diabetes_y_test, diabetes_y_pred))

# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(diabetes_y_test, diabetes_y_pred))
# Out:
# Coefficients:
#  [684.71759186]
# Mean squared: 63.53
# Coefficient of determination: 0.32

# %%
# Plots output
plt.scatter(diabetes_X_test, diabetes_y_test, color='black')
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
