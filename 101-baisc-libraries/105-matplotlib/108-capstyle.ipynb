# %%
import matplotlib.pyplot as plt
from matplotlib._enums import CapStyle

# %%
CapStyle.demo()
plt.show()
# Out:
# /tmp/ipykernel_401589/1995337425.py:1: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   CapStyle.demo()
