# %%
import pandas as pd

# %%
EGG_FILE = "/home/nitish/Documents/paradox/github/ArtOfAI/101-baisc-libraries/104-pandas/titanic3.xls"
SPOTIFY_DATA = "/home/nitish/Documents/paradox/github/ArtOfAI/101-baisc-libraries/104-pandas/spotify.csv"

# %% [markdown]
# # How do I read and write tabular data?
#
# I want to analyze the data in the csv file.

# %%
spotify = pd.read_csv(SPOTIFY_DATA)

# %% [markdown]
# pandas provides the `read_csv()` function to read data stored as a csv file into a pandas `DataFrame`. pandas supports many different file formats or data sources out of the box (csv, excel, sql, json, parquet, ...), each of them with the prefix `read_*`.

# %% [markdown]
# Make sure to always have to check on the data after reading in the data. When displaying a `DataFrame`, the first and last 5 rows will be shown be default:

# %%
spotify
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 0    2017-01-06      12287078        NaN                       NaN        NaN
# 1    2017-01-07      13190270        NaN                       NaN        NaN
# 2    2017-01-08      13099919        NaN                       NaN        NaN
# 3    2017-01-09      14506351        NaN                       NaN        NaN
# 4    2017-01-10      14275628        NaN                       NaN        NaN
# ..          ...           ...        ...                       ...        ...
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# ...

# %% [markdown]
# I want to see the first 8 rows of a pandas DataFrame.

# %%
spotify.head(8)
# Out:
#          Date  Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# 0  2017-01-06      12287078        NaN                       NaN      NaN
# 1  2017-01-07      13190270        NaN                       NaN      NaN
# 2  2017-01-08      13099919        NaN                       NaN      NaN
# 3  2017-01-09      14506351        NaN                       NaN      NaN
# 4  2017-01-10      14275628        NaN                       NaN      NaN
# 5  2017-01-11      14372699        NaN                       NaN      NaN
# 6  2017-01-12      14148108        NaN                       NaN      NaN
# 7  2017-01-13      14536236   275178.0                       NaN      NaN
#
#    Unforgettable
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN

# %% [markdown]
# To see the first N rows of a `DataFrame`, use the `head()` method with the required number of rows (in this case 8) as argument.
#
# To see the N rows from the last, use the `tail()`

# %%
spotify.tail(10)
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 356  2017-12-31       7073032  8203454.0                 3514602.0  2787752.0
# 357  2018-01-01       4865387  5557165.0                 2179506.0  2368321.0
# 358  2018-01-02       4541816  3980200.0                 2368870.0  2505241.0
# 359  2018-01-03       4596993  3890385.0                 2363422.0  2587620.0
# 360  2018-01-04       4447076  3512667.0                 2345804.0  2575748.0
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# 356      3792953.0
# 357      2537274.0
# 358      2683769.0
# 359      2753557.0
# ...

# %% [markdown]
# A check on how pandas interpreted each of the column data types can be done by requesting the pandas `dtypes` attribute:

# %%
spotify.dtypes
# Out:
# Date                         object
# Shape of You                  int64
# Despacito                   float64
# Something Just Like This    float64
# HUMBLE.                     float64
# Unforgettable               float64
# dtype: object

# %% [markdown]
# For each of the columns, the used data type is enlisted. The data types in this `DataFrame` are integers (`int64`), floats (`float64`) and string (`object`).

# %% [markdown]
# ### If you want to data as a spreadsheet

# %%
# it will save the data to spreadsheet (excel)

spotify.to_excel("spotify.xlsx", sheet_name="spotify", index=False)

# %% [markdown]
# Whereas `read_*` function are used to read data to pandas, the `to_*` methods are used to store data. The `to_excel()` method stores the data as an excel file.
#
# In the example here, the `sheet_name` is named *passengers* instead of the default *Sheet1*. By setting `index=False` the row index labels are not saved in the spreadsheet.

# %%
spotify_excel = pd.read_excel("spotify.xlsx", sheet_name="spotify")

# %%
spotify_excel.head(2)
# Out:
#          Date  Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# 0  2017-01-06      12287078        NaN                       NaN      NaN
# 1  2017-01-07      13190270        NaN                       NaN      NaN
#
#    Unforgettable
# 0            NaN
# 1            NaN

# %%
spotify_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      366 non-null    object
#  1   Shape of You              366 non-null    int64
#  2   Despacito                 359 non-null    float64
#  3   Something Just Like This  319 non-null    float64
#  4   HUMBLE.                   282 non-null    float64
#  5   Unforgettable             275 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 17.3+ KB

# %% [markdown]
# The method `info()` provides technical information about a `DataFrame`.
