# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
fifa = pd.read_csv(
    "fifa.csv",
    index_col=0,
    parse_dates=True
)

# %%
fifa.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %% [markdown]
# The usage of the `index_col` and `parse_dates` parameters of the `read_csv` function to define the first (0th) column as index of the resulting `DataFrame` and convert the dates in the function to the `Timestamp` objects, respectively.

# %% [markdown]
# #### I want to quick visual check of the data.

# %%
fifa.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# plt.show()

# %% [markdown]
# With a `DataFrame`, pandas creates by default one line plot for each of the columns with numeric data.

# %% [markdown]
# ### I want to plot only the columns of the data table with the data from "ARG".

# %%
fifa['ARG'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# To plot a specific  column, use the selection method of the subset data in combination with the `plot()` method. Hence, the `plot()` works on both `Series` and `DataFrame`.

# %% [markdown]
# ### I want a scatter between 'Brazil', and 'Argentina'

# %%
fifa.plot.scatter(x='ARG', y='BRA', alpha=0.5)
# Out:
# <Axes: xlabel='ARG', ylabel='BRA'>

# %% [markdown]
# Apart from the default `line` plot when using the `plot` function, a number of alternatives are available to plot data. Let's use some standard Python to get an overview of the available plot methods:

# %%
[
    method_name for method_name in dir(fifa.plot) if not method_name.startswith("_")
]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %% [markdown]
# ### I want each of the columns in a separate subplot

# %%
axs = fifa.plot.area(figsize=(12, 7), subplots=True)

# %% [markdown]
# Separate subplots for each of the data columns are supported by the `subplots` argument of the `plot` functions. The builtin options avaiable in each of the pandas plot functions are worth reviewing.

# %% [markdown]
# ### I want to further customize, extend and save the resulting plot

# %%
# Create an empty Matplotlib Figure and Axes
fig, axs = plt.subplots(figsize=(12, 4))

 # Use pandas to put the area plot on the prepared Figure/Axes
fifa.plot.area(ax=axs)

# Do any Matplotlib customization you like
axs.set_ylabel("Goals")

# Save the Figure/Axes using the existing Matplotlib method.
fig.savefig("fifa graphs.png")

# Display the plot
plt.show()

# %% [markdown]
# Each of the plot objects created by pandas is a `Matplotlib` object. As Matplotlib provides plenty of options to customize plots, making the link between pandas and Matplotlib explicit enables all the power of Matplotlib to the plot.
